# %%
import tensorflow as tf
import numpy as np

print(tf.__version__)
print(np.__version__)
# Out:
# 2.6.0
# 1.21.4

# %%
from PIL import Image
import glob
import os

print("PIL 라이브러리 import 완료!")
# Out:
# PIL 라이브러리 import 완료!

# %%
image_size = 224

augment_flag = False
#augment_flag = True

#model = "model_1"  # base
# model = "model_2" #resnet v2 나름 괜찮음.       conv_5 block_3부터 재학습하면 max val_acc 0.79
#model = "model_3"                               #efficientnet b4 # 전혀 학습이 안됨. val_accuracy 0.17 근처(~ 1/ 6)
# model = "model_4" #MoblileNet v2 # 
model = "model_5" # DenseNet121

# base_model_trainable = False
base_model_trainable = True

if model == "model_1":
    pass
elif model == "model_2":
    train_layer_from = 177                # conv_5 block_3부터 재학습
elif model == "model_3":
    train_layer_from = 177
elif model == "model_4":
    train_layer_from = 141              # 144
elif model == "model_5":
    train_layer_from = 313              #144 test accuracy 0.8974
    
n_train_epoch = 50

#rgb_stardardization = True
rgb_standardization = True

# %% [markdown]
# ## 데이터 불러 오기

# %% [markdown]
# ### 데이터 로드 함수 정의

# %%
import os
from PIL import Image

# 하나의 디렉토리(dir_path)의 이미지화일(.jpg, .jpeg)을 읽어서 list를 리턴하는 함수
# 이 때 이미지를 (target_size, target_size)로 리사이즈 한다.
def load_images_from_dir(dir_path, target_size = 224):
    """
    Loads all '.jpg' and '.jpeg' files from a directory, including its subdirectories.
    This function is case-insensitive for file extensions.

    :param root_directory: The root directory to start the search from.
    :return: A list of PIL Image objects.
    """
    images = []
    for root, dirs, files in os.walk(dir_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg')):
                file_path = os.path.join(root, file)
                try:
                    img = Image.open(file_path)
                    new_img = img.resize((target_size, target_size),Image.ANTIALIAS)
                    images.append(new_img)
                except IOError:
                    print(f"Cannot load image: {file_path}")
    return images

# %% [markdown]
# ### 이미지 화일을 읽어서 폴더별로 라벨링 한다.
# - 라벨은 헤당 클래스가 class_dir_list에 나타나는 순서

# %%
# import numpy as np
import os

class_dir_list = ["barrel_jellyfish",          # 0
                    "blue_jellyfish",          # 1
                   "compass_jellyfish",        # 2
                   "lions_mane_jellyfish",     # 3
                    "mauve_stinger_jellyfish", # 4
                    "Moon_jellyfish"]          # 5

# 하위 디렉토리(class_dir_list에 있는)를 순회하면서 이미지 화일을 읽고
# 디렉토리에 따라 라벨링을 해준다.
# 라벨은 class_dir_list에 나타나는 해파리명의 순서
# def load_data_with_label(img_path, max_number_of_data=10000, class_dir_list = ""):  # 가위바위보 이미지 개수 총합에 주의하세요.
#     # 가위 : 0, 바위 : 1, 보 : 2
#     img_size=224
#     color=3

#     #이미지 데이터와 라벨(가위 : 0, 바위 : 1, 보 : 2) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
#     images=np.zeros(max_number_of_data*img_size*img_size*color,dtype=np.int32).reshape(max_number_of_data,img_size,img_size,color)
#     labels=np.zeros(max_number_of_data,dtype=np.int32)

#     idx=0
    
#     for label, dir_name in enumerate(class_dir_list):
#         class_image_dir = img_path + "/" + dir_name
#         class_images = load_images_from_dir(class_image_dir)
#         for i in range(len(class_images)):
#             images[idx, :, :, :] = class_images[i]
#             labels[idx] = label
#             idx += 1
    
#     print("데이터의 이미지 개수는", idx,"입니다.")
#     images = images[:idx]
#     labels = labels[:idx]

#     return images, labels
def load_data_with_label(img_root_list, img_sub_dir, max_number_of_data=10000, class_dir_list = ""):  # 가위바위보 이미지 개수 총합에 주의하세요.
    # 가위 : 0, 바위 : 1, 보 : 2
    img_size=224
    color=3

    #이미지 데이터와 라벨(가위 : 0, 바위 : 1, 보 : 2) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    images=np.zeros(max_number_of_data*img_size*img_size*color,dtype=np.int32).reshape(max_number_of_data,img_size,img_size,color)
    labels=np.zeros(max_number_of_data,dtype=np.int32)

    idx=0
    
    for img_root_dir in img_root_list:
        img_path = img_root_dir + img_sub_dir
        print(img_path)
        for label, dir_name in enumerate(class_dir_list):
            class_image_dir = img_path + "/" + dir_name
            class_images = load_images_from_dir(class_image_dir)
            for i in range(len(class_images)):
                images[idx, :, :, :] = class_images[i]
                labels[idx] = label
                idx += 1
    
    print("데이터의 이미지 개수는", idx,"입니다.")
    images = images[:idx]
    labels = labels[:idx]

    return images, labels

# %%
#img_root_list = ["/aiffel/aiffel/jellyfish/Train_Test_Valid/"]
img_root_list = ["/aiffel/aiffel/jellyfish/Train_Test_Valid/", "/aiffel/aiffel/jellyfish/add_data/"]
#img_root_list = ["/aiffel/aiffel/jellyfish/Label_Reviewed/Train_Test_Valid/"]

# img_root_list = ["/aiffel/aiffel/jellyfish/Train_Test_Valid/",
#              "/aiffel/aiffel/jellyfish/Add_Data/"]

# img_root_list = ["/aiffel/aiffel/jellyfish/Label_Reviewed/Train_Test_Valid/",
#              "/aiffel/aiffel/jellyfish/Add_Data/"]

#img_root_list = ["/aiffel/aiffel/jellyfish/Add_Data/"]


train_data, train_labels = load_data_with_label(img_root_list, "Train",
                           class_dir_list = class_dir_list)

val_data, val_labels = load_data_with_label(img_root_list, "valid",
                           class_dir_list = class_dir_list)

test_data, test_labels = load_data_with_label(img_root_list, "test",
                           class_dir_list = class_dir_list)
# Out:
# /aiffel/aiffel/jellyfish/Train_Test_Valid/Train
# /aiffel/aiffel/jellyfish/add_data/Train
# 데이터의 이미지 개수는 1293 입니다.
# /aiffel/aiffel/jellyfish/Train_Test_Valid/valid
# /aiffel/aiffel/jellyfish/add_data/valid
# 데이터의 이미지 개수는 100 입니다.
# /aiffel/aiffel/jellyfish/Train_Test_Valid/test
# /aiffel/aiffel/jellyfish/add_data/test
# 데이터의 이미지 개수는 39 입니다.

# %% [markdown]
# ### train, validataion, test data와 label을 로드한다.

# %%
# file_root = "/aiffel/aiffel/jellyfish/Train_Test_Valid/"

# train_data, train_labels = load_data_with_label(file_root + "Train",
#                            class_dir_list = class_dir_list)

# val_data, val_labels = load_data_with_label(file_root + "valid",
#                            class_dir_list = class_dir_list)

# test_data, test_labels = load_data_with_label(file_root + "test",
#                            class_dir_list = class_dir_list)

# %%
import tensorflow as tf

def rotate_image(image):
    return tf.image.rot90(image)

def zoom_image(image, size=(224, 224)):
    # 이미지 중앙을 기준으로 확대 후 원본 크기로 조정
    zoomed = tf.image.central_crop(image, 0.8)
    return tf.image.resize(zoomed, size)

def adjust_contrast_image(image):
    adjusted_image = tf.image.random_contrast(image, lower=0.2, upper=1.8)
    clipped_image = tf.clip_by_value(adjusted_image, 0, 255)

    return clipped_image

def adjust_brightness_image(image):
    adjusted_image = tf.image.random_brightness(image, max_delta=0.2)
    clipped_image = tf.clip_by_value(adjusted_image, 0, 255)
    
    return clipped_image

def flip_left_right_image(image):
    return tf.image.flip_left_right(image)

def augment_dataset_with_labels(data, labels):
    augmented_data = []
    augmented_labels = []

    for image, label in zip(data, labels):
        augmented_images = [
            image,
            rotate_image(image).numpy(),
            #flip_left_right_image(image).numpy(),
            #zoom_image(image).numpy()
            adjust_contrast_image(image).numpy()
            #adjust_brightness_image(image).numpy()
        ]

        for aug_image in augmented_images:
            augmented_data.append(aug_image)
            augmented_labels.append(label)

    return np.array(augmented_data), np.array(augmented_labels)

# 데이터셋 적용 예시
# train_data, train_label = ...

if augment_flag:
    train_data, train_labels = augment_dataset_with_labels(train_data, train_labels)

# %%
train_data.shape
# Out:
# (1293, 224, 224, 3)

# %% [markdown]
# ### 로드한 이미지 그려 보기

# %%
import matplotlib.pyplot as plt

def show_images_in_matrix(images, rows=4, cols=4):
    """
    Displays images in a grid format using matplotlib.

    :param images: A list of PIL Image objects.
    :param rows: The number of rows in the image grid.
    :param cols: The number of columns in the image grid.
    """
    fig, axes = plt.subplots(rows, cols, figsize=(12, 12))
    axes = axes.ravel()

    for i in range(rows * cols):
        if i < len(images):
            axes[i].imshow(images[i])
            axes[i].axis('off')
        else:
            axes[i].axis('off')

    plt.tight_layout()
    plt.show()
    
show_images_in_matrix(train_data[:16])
    
# Example usage:
# images = [Your list of PIL Image objects]
# show_images_in_matrix(images)

# Replace [Your list of PIL Image objects] with a list of PIL Image objects.

# %% [markdown]
# ### 데이터 shape 확인

# %%
print(train_data.shape)
print(train_labels.shape)

print(val_data.shape)
print(val_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1293, 224, 224, 3)
# (1293,)
# (100, 224, 224, 3)
# (100,)
# (39, 224, 224, 3)
# (39,)

# %% [markdown]
# ### 데이터 scale 조정

# %%
def standardize_dataset(data):
    # 데이터셋 전체에 대한 평균과 표준편차를 계산
    mean = np.mean(data, axis=(0, 1, 2))
    std = np.std(data, axis=(0, 1, 2))

    # 데이터셋을 표준화
    standardized_data = (data - mean) / std
    return standardized_data

if rgb_standardization:
    # 가정: data는 (data_num, 224, 224, 3) 형태의 NumPy 배열
    train_data_std = standardize_dataset(train_data)
    val_data_std = standardize_dataset(val_data)
    test_data_std = standardize_dataset(test_data)
else:
    train_data_std = train_data / 255.0   # 입력은 0~1 사이의 값으로 정규화
    val_data_std = val_data / 255.0   # 입력은 0~1 사이의 값으로 정규화
    test_data_std = test_data / 255.0   # 입력은 0~1 사이의 값으로 정규화

print("train_data shape: {}".format(train_data_std.shape))
print("train_label shape: {}".format(train_labels.shape))
# Out:
# train_data shape: (1293, 224, 224, 3)
# train_label shape: (1293,)

# %% [markdown]
# ### train data 섞기

# %%
import numpy as np

# 인덱스 배열 생성
indices = np.arange(len(train_data))

# 인덱스 배열을 무작위로 섞기
np.random.shuffle(indices)

# 인덱스를 사용하여 데이터와 라벨을 섞기
train_data = train_data[indices]
train_data_std = train_data_std[indices]
train_labels = train_labels[indices]

# %% [markdown]
# ### 스케일 조정된 데이터 확인

# %%
train_data_std[0]
# Out:
# array([[[-0.42568634, -0.84628086, -0.68142838],
#         [-0.38417054, -0.80193361, -0.63968753],
#         [-0.34265474, -0.75758636, -0.59794667],
#         ...,
#         [-0.31497754, -0.66889187, -0.4727241 ],
#         [-0.31497754, -0.66889187, -0.4727241 ],
#         [-0.31497754, -0.66889187, -0.4727241 ]],
#
#        [[-0.41184774, -0.83149844, -0.66751477],
#         [-0.38417054, -0.80193361, -0.63968753],
#         [-0.34265474, -0.75758636, -0.59794667],
#         ...,
#         [-0.31497754, -0.66889187, -0.4727241 ],
#         [-0.31497754, -0.66889187, -0.4727241 ],
#         [-0.31497754, -0.66889187, -0.4727241 ]],
#
#        [[-0.39800914, -0.81671602, -0.65360115],
#         [-0.37033194, -0.78715119, -0.62577391],
#         [-0.34265474, -0.75758636, -0.59794667],
#         ...,
#         [-0.31497754, -0.66889187, -0.4727241 ],
#         [-0.31497754, -0.66889187, -0.4727241 ],
#         [-0.31497754, -0.66889187, -0.4727241 ]],
#
#        ...,
#
#        [[-0.56407233, -0.93497535, -1.11275057],
#         [-0.56407233, -0.93497535, -1.11275057],
#         [-0.55023373, -0.92019293, -1.09883695],
#         ...,
#         [-0.49487933, -0.86106327, -1.01535524],
#         [-0.49487933, -0.86106327, -1.01535524],
#         [-0.49487933, -0.86106327, -1.01535524]],
#
#        [[-0.56407233, -0.93497535, -1.11275057],
#         [-0.56407233, -0.93497535, -1.11275057],
#         [-0.56407233, -0.93497535, -1.11275057],
#         ...,
#         [-0.49487933, -0.86106327, -1.01535524],
#         [-0.49487933, -0.86106327, -1.01535524],
#         [-0.49487933, -0.86106327, -1.01535524]],
#
#        [[-0.56407233, -0.93497535, -1.11275057],
#         [-0.56407233, -0.93497535, -1.11275057],
#         [-0.56407233, -0.93497535, -1.11275057],
#         ...,
#         [-0.49487933, -0.86106327, -1.01535524],
#         [-0.49487933, -0.86106327, -1.01535524],
#         [-0.49487933, -0.86106327, -1.01535524]]])

# %% [markdown]
# ### 모델 정의
# - LeNet의 정의을 그대로 따랐다.
# - 가장 큰 차이는 convolution layer를 하나 더 넣었다는 것이다.

# %%
# pretrained model retrain 정도 결정 함수

# base_model : pretrained model
# model_trainable : 모델이 retrainable 한가? False면 retrain_layer_from에 상관없이 retrain 안함
# train_layer_from : 어떤 layer부터 retrain할 것인가?
#    retrain 가능한 layer를 보여준다.
def set_base_model_retrainable(base_model, 
                               model_trainable = False, 
                               train_layer_from = 0):
    base_model.trainable = model_trainable
    if (model_trainable):
        if (train_layer_from < len(base_model.layers)):
            for layer in base_model.layers[:train_layer_from]:
                layer.trainable = False

        print("[Retrainable layers]")        
        for i, layer in enumerate(base_model.layers):
            if layer.trainable:
                print(i, layer.name)

# base_model = tf.keras.applications.resnet_v2.ResNet50V2(input_shape = (image_size, image_size, 3),
#                          include_top=False,
#                          weights='imagenet')

# set_base_model_retrainable(base_model, True, train_layer_from = 100)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, Input, Concatenate, GlobalAveragePooling2D
from tensorflow.keras import backend as K


import numpy as np

if model == "model_1":
    # 모델 1
    # model을 직접 만들어 보세요.
    # Hint! model의 입력/출력부에 특히 유의해 주세요. 가위바위보 데이터셋은 MNIST 데이터셋과 어떤 점이 달라졌나요?
    n_channel_1=32
    n_channel_2=64
    n_channel_3=128
    n_channel_4=256
    n_dense_1= 128
    n_dense_2 = 64
    #n_train_epoch=50

    model=keras.models.Sequential()
    model.add(keras.layers.Conv2D(n_channel_1, (3,3), \
                                  activation='relu', \
                                  input_shape=(image_size,image_size,3)))
    model.add(keras.layers.MaxPool2D(2,2))
    model.add(keras.layers.Normalization())
    model.add(keras.layers.Conv2D(n_channel_2, (3,3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2,2)))
    model.add(keras.layers.Normalization())
    model.add(keras.layers.Conv2D(n_channel_3, (3,3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2,2)))
    model.add(keras.layers.Conv2D(n_channel_4, (3,3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2,2)))

    model.add(keras.layers.Flatten())
    #model.add(keras.layers.Dense(n_dense_1, activation='relu'))
    #model.add(keras.layers.BatchNormalization())  # Batch Normalization
    model.add(keras.layers.Dense(n_dense_2, activation='relu'))
    #model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(6, activation='softmax'))
elif model == "model_2":
    # 모델 2
    # Create the base model from the pre-trained model VGG16
    base_model = tf.keras.applications.resnet_v2.ResNet50V2(input_shape = (image_size, image_size, 3),
                                             include_top=False,
                                             weights='imagenet')
    input = tf.keras.layers.Input(shape = (image_size, image_size, 3))
    feature_batch = base_model(input)

    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    
    #inputs = tf.keras.Input(shape = (image_size, image_size, 3))
    feature_batch_average = global_average_layer(feature_batch)

    dense_layer = tf.keras.Sequential([
      tf.keras.layers.Dense(units = 32),
      #tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Activation("relu")]
    )

    batch_layer = tf.keras.layers.BatchNormalization()

    dense_layer_2 = tf.keras.Sequential([
      tf.keras.layers.Dense(units = 32),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Activation("relu")]
    )

    prediction_layer = Dense(units = 6, activation = "softmax")

    # feature_batch_averag가 dense_layer를 거친 결과가 다시 prediction_layer를 거치게 되면
    prediction_batch = prediction_layer(dense_layer(feature_batch_average))  

    set_base_model_retrainable(base_model, base_model_trainable, train_layer_from)
#     base_model.trainable = False
#     if (base_model_trainable):
#         base_model.trainable = True

#         for layer in base_model.layers[:177]:
#         #for layer in base_model.layers[:154]:
#         #for layer in base_model.layers[:76]:
#             layer.trainable = False

#     for i, layer in enumerate(base_model.layers):
#         if layer.trainable:
#             print(i, layer.name, layer.trainable)

    model = tf.keras.Sequential([
      base_model,
      global_average_layer,
      dense_layer,
      #batch_layer,
      #dense_layer_2,
      prediction_layer
    ])
elif model == "model_3": # 전혀 학습이 안됨. val_accuracy 0.17 근처(~ 1/ 6)
    # 사전 훈련된 EfficientNet B4 모델 불러오기
    base_model = tf.keras.applications.EfficientNetB4(weights='imagenet', 
                                                     include_top=False, input_shape=(image_size, image_size, 3))

    set_base_model_retrainable(base_model, base_model_trainable, train_layer_from)

    input = tf.keras.layers.Input(shape = (image_size, image_size, 3))

    # 새로운 분류 레이어 추가
    x = base_model(input)
    x = GlobalAveragePooling2D()(x)
    x = Dense(32, activation='relu')(x)
    predictions = Dense(6, activation='softmax')(x)  # num_classes는 데이터셋의 클래스 수

    # 최종 모델 정의
    model = Model(inputs=input, outputs=predictions)
elif model == "model_4":
    
    base_model = tf.keras.applications.MobileNetV2(weights='imagenet', 
                                                    include_top=False, input_shape=(image_size, image_size, 3))
    #print(base_model_trainable)
    set_base_model_retrainable(base_model, base_model_trainable, train_layer_from)

    input = tf.keras.layers.Input(shape = (image_size, image_size, 3))

    # 새로운 분류 레이어 추가
    x = base_model(input)
    x = GlobalAveragePooling2D()(x)
    x = Dense(32, activation='relu')(x)
    predictions = Dense(6, activation='softmax')(x)  # num_classes는 데이터셋의 클래스 수

    # 최종 모델 정의
    model = Model(inputs=input, outputs=predictions)
elif model == "model_5":
    base_model = tf.keras.applications.DenseNet121(weights='imagenet', 
                                                    include_top=False, input_shape=(image_size, image_size, 3))
    set_base_model_retrainable(base_model, base_model_trainable, train_layer_from)

    input = tf.keras.layers.Input(shape = (image_size, image_size, 3))

    # 새로운 분류 레이어 추가
    x = base_model(input)
    x = GlobalAveragePooling2D()(x)
    x = DropOut(0.35)(x)
    x = Dense(32, activation='relu')(x)
    x = DropOut(0.35)(x)
    predictions = Dense(6, activation='softmax')(x)  # num_classes는 데이터셋의 클래스 수

    # 최종 모델 정의
    model = Model(inputs=input, outputs=predictions)



model.summary()
# Out:
# [Retrainable layers]
# 100 conv3_block7_2_conv
# 101 conv3_block7_concat
# 102 conv3_block8_0_bn
# 103 conv3_block8_0_relu
# 104 conv3_block8_1_conv
# 105 conv3_block8_1_bn
# 106 conv3_block8_1_relu
# 107 conv3_block8_2_conv
# 108 conv3_block8_concat
# 109 conv3_block9_0_bn
# 110 conv3_block9_0_relu
# 111 conv3_block9_1_conv
# 112 conv3_block9_1_bn
# 113 conv3_block9_1_relu
# 114 conv3_block9_2_conv
# 115 conv3_block9_concat
# 116 conv3_block10_0_bn
# 117 conv3_block10_0_relu
# 118 conv3_block10_1_conv
# 119 conv3_block10_1_bn
# 120 conv3_block10_1_relu
# 121 conv3_block10_2_conv
# 122 conv3_block10_concat
# 123 conv3_block11_0_bn
# 124 conv3_block11_0_relu
# 125 conv3_block11_1_conv
# 126 conv3_block11_1_bn
# 127 conv3_block11_1_relu
# 128 conv3_block11_2_conv
# 129 conv3_block11_concat
# 130 conv3_block12_0_bn
# 131 conv3_block12_0_relu
# 132 conv3_block12_1_conv
# 133 conv3_block12_1_bn
# 134 conv3_block12_1_relu
# 135 conv3_block12_2_conv
# 136 conv3_block12_concat
# 137 pool3_bn
# 138 pool3_relu
# 139 pool3_conv
# 140 pool3_pool
# 141 conv4_block1_0_bn
# 142 conv4_block1_0_relu
# 143 conv4_block1_1_conv
# 144 conv4_block1_1_bn
# 145 conv4_block1_1_relu
# 146 conv4_block1_2_conv
# 147 conv4_block1_concat
# 148 conv4_block2_0_bn
# 149 conv4_block2_0_relu
# 150 conv4_block2_1_conv
# 151 conv4_block2_1_bn
# 152 conv4_block2_1_relu
# 153 conv4_block2_2_conv
# 154 conv4_block2_concat
# 155 conv4_block3_0_bn
# 156 conv4_block3_0_relu
# 157 conv4_block3_1_conv
# 158 conv4_block3_1_bn
# 159 conv4_block3_1_relu
# 160 conv4_block3_2_conv
# 161 conv4_block3_concat
# 162 conv4_block4_0_bn
# 163 conv4_block4_0_relu
# 164 conv4_block4_1_conv
# 165 conv4_block4_1_bn
# 166 conv4_block4_1_relu
# 167 conv4_block4_2_conv
# 168 conv4_block4_concat
# 169 conv4_block5_0_bn
# 170 conv4_block5_0_relu
# 171 conv4_block5_1_conv
# 172 conv4_block5_1_bn
# 173 conv4_block5_1_relu
# 174 conv4_block5_2_conv
# 175 conv4_block5_concat
# 176 conv4_block6_0_bn
# 177 conv4_block6_0_relu
# 178 conv4_block6_1_conv
# 179 conv4_block6_1_bn
# 180 conv4_block6_1_relu
# 181 conv4_block6_2_conv
# 182 conv4_block6_concat
# 183 conv4_block7_0_bn
# 184 conv4_block7_0_relu
# 185 conv4_block7_1_conv
# 186 conv4_block7_1_bn
# 187 conv4_block7_1_relu
# 188 conv4_block7_2_conv
# 189 conv4_block7_concat
# 190 conv4_block8_0_bn
# 191 conv4_block8_0_relu
# 192 conv4_block8_1_conv
# 193 conv4_block8_1_bn
# 194 conv4_block8_1_relu
# 195 conv4_block8_2_conv
# 196 conv4_block8_concat
# 197 conv4_block9_0_bn
# 198 conv4_block9_0_relu
# 199 conv4_block9_1_conv
# 200 conv4_block9_1_bn
# 201 conv4_block9_1_relu
# 202 conv4_block9_2_conv
# 203 conv4_block9_concat
# 204 conv4_block10_0_bn
# 205 conv4_block10_0_relu
# 206 conv4_block10_1_conv
# 207 conv4_block10_1_bn
# 208 conv4_block10_1_relu
# 209 conv4_block10_2_conv
# 210 conv4_block10_concat
# 211 conv4_block11_0_bn
# 212 conv4_block11_0_relu
# 213 conv4_block11_1_conv
# 214 conv4_block11_1_bn
# 215 conv4_block11_1_relu
# 216 conv4_block11_2_conv
# 217 conv4_block11_concat
# 218 conv4_block12_0_bn
# 219 conv4_block12_0_relu
# 220 conv4_block12_1_conv
# 221 conv4_block12_1_bn
# 222 conv4_block12_1_relu
# 223 conv4_block12_2_conv
# 224 conv4_block12_concat
# 225 conv4_block13_0_bn
# 226 conv4_block13_0_relu
# 227 conv4_block13_1_conv
# 228 conv4_block13_1_bn
# 229 conv4_block13_1_relu
# 230 conv4_block13_2_conv
# 231 conv4_block13_concat
# 232 conv4_block14_0_bn
# 233 conv4_block14_0_relu
# 234 conv4_block14_1_conv
# 235 conv4_block14_1_bn
# 236 conv4_block14_1_relu
# 237 conv4_block14_2_conv
# 238 conv4_block14_concat
# 239 conv4_block15_0_bn
# 240 conv4_block15_0_relu
# 241 conv4_block15_1_conv
# 242 conv4_block15_1_bn
# 243 conv4_block15_1_relu
# 244 conv4_block15_2_conv
# 245 conv4_block15_concat
# 246 conv4_block16_0_bn
# 247 conv4_block16_0_relu
# 248 conv4_block16_1_conv
# 249 conv4_block16_1_bn
# 250 conv4_block16_1_relu
# 251 conv4_block16_2_conv
# 252 conv4_block16_concat
# 253 conv4_block17_0_bn
# 254 conv4_block17_0_relu
# 255 conv4_block17_1_conv
# 256 conv4_block17_1_bn
# 257 conv4_block17_1_relu
# 258 conv4_block17_2_conv
# 259 conv4_block17_concat
# 260 conv4_block18_0_bn
# 261 conv4_block18_0_relu
# 262 conv4_block18_1_conv
# 263 conv4_block18_1_bn
# 264 conv4_block18_1_relu
# 265 conv4_block18_2_conv
# 266 conv4_block18_concat
# 267 conv4_block19_0_bn
# 268 conv4_block19_0_relu
# 269 conv4_block19_1_conv
# 270 conv4_block19_1_bn
# 271 conv4_block19_1_relu
# 272 conv4_block19_2_conv
# 273 conv4_block19_concat
# 274 conv4_block20_0_bn
# 275 conv4_block20_0_relu
# 276 conv4_block20_1_conv
# 277 conv4_block20_1_bn
# 278 conv4_block20_1_relu
# 279 conv4_block20_2_conv
# 280 conv4_block20_concat
# 281 conv4_block21_0_bn
# 282 conv4_block21_0_relu
# 283 conv4_block21_1_conv
# 284 conv4_block21_1_bn
# 285 conv4_block21_1_relu
# 286 conv4_block21_2_conv
# 287 conv4_block21_concat
# 288 conv4_block22_0_bn
# 289 conv4_block22_0_relu
# 290 conv4_block22_1_conv
# 291 conv4_block22_1_bn
# 292 conv4_block22_1_relu
# 293 conv4_block22_2_conv
# 294 conv4_block22_concat
# 295 conv4_block23_0_bn
# 296 conv4_block23_0_relu
# 297 conv4_block23_1_conv
# 298 conv4_block23_1_bn
# 299 conv4_block23_1_relu
# 300 conv4_block23_2_conv
# 301 conv4_block23_concat
# 302 conv4_block24_0_bn
# 303 conv4_block24_0_relu
# 304 conv4_block24_1_conv
# 305 conv4_block24_1_bn
# 306 conv4_block24_1_relu
# 307 conv4_block24_2_conv
# 308 conv4_block24_concat
# 309 pool4_bn
# 310 pool4_relu
# 311 pool4_conv
# 312 pool4_pool
# 313 conv5_block1_0_bn
# 314 conv5_block1_0_relu
# 315 conv5_block1_1_conv
# 316 conv5_block1_1_bn
# 317 conv5_block1_1_relu
# 318 conv5_block1_2_conv
# 319 conv5_block1_concat
# 320 conv5_block2_0_bn
# 321 conv5_block2_0_relu
# 322 conv5_block2_1_conv
# 323 conv5_block2_1_bn
# 324 conv5_block2_1_relu
# 325 conv5_block2_2_conv
# 326 conv5_block2_concat
# 327 conv5_block3_0_bn
# 328 conv5_block3_0_relu
# 329 conv5_block3_1_conv
# 330 conv5_block3_1_bn
# 331 conv5_block3_1_relu
# 332 conv5_block3_2_conv
# 333 conv5_block3_concat
# 334 conv5_block4_0_bn
# 335 conv5_block4_0_relu
# 336 conv5_block4_1_conv
# 337 conv5_block4_1_bn
# 338 conv5_block4_1_relu
# 339 conv5_block4_2_conv
# 340 conv5_block4_concat
# 341 conv5_block5_0_bn
# 342 conv5_block5_0_relu
# 343 conv5_block5_1_conv
# 344 conv5_block5_1_bn
# 345 conv5_block5_1_relu
# 346 conv5_block5_2_conv
# 347 conv5_block5_concat
# 348 conv5_block6_0_bn
# 349 conv5_block6_0_relu
# 350 conv5_block6_1_conv
# 351 conv5_block6_1_bn
# 352 conv5_block6_1_relu
# 353 conv5_block6_2_conv
# 354 conv5_block6_concat
# 355 conv5_block7_0_bn
# 356 conv5_block7_0_relu
# 357 conv5_block7_1_conv
# 358 conv5_block7_1_bn
# 359 conv5_block7_1_relu
# 360 conv5_block7_2_conv
# 361 conv5_block7_concat
# 362 conv5_block8_0_bn
# 363 conv5_block8_0_relu
# 364 conv5_block8_1_conv
# 365 conv5_block8_1_bn
# 366 conv5_block8_1_relu
# 367 conv5_block8_2_conv
# 368 conv5_block8_concat
# 369 conv5_block9_0_bn
# 370 conv5_block9_0_relu
# 371 conv5_block9_1_conv
# 372 conv5_block9_1_bn
# 373 conv5_block9_1_relu
# 374 conv5_block9_2_conv
# 375 conv5_block9_concat
# 376 conv5_block10_0_bn
# 377 conv5_block10_0_relu
# 378 conv5_block10_1_conv
# 379 conv5_block10_1_bn
# 380 conv5_block10_1_relu
# 381 conv5_block10_2_conv
# 382 conv5_block10_concat
# 383 conv5_block11_0_bn
# 384 conv5_block11_0_relu
# 385 conv5_block11_1_conv
# 386 conv5_block11_1_bn
# 387 conv5_block11_1_relu
# 388 conv5_block11_2_conv
# 389 conv5_block11_concat
# 390 conv5_block12_0_bn
# 391 conv5_block12_0_relu
# 392 conv5_block12_1_conv
# 393 conv5_block12_1_bn
# 394 conv5_block12_1_relu
# 395 conv5_block12_2_conv
# 396 conv5_block12_concat
# 397 conv5_block13_0_bn
# 398 conv5_block13_0_relu
# 399 conv5_block13_1_conv
# 400 conv5_block13_1_bn
# 401 conv5_block13_1_relu
# 402 conv5_block13_2_conv
# 403 conv5_block13_concat
# 404 conv5_block14_0_bn
# 405 conv5_block14_0_relu
# 406 conv5_block14_1_conv
# 407 conv5_block14_1_bn
# 408 conv5_block14_1_relu
# 409 conv5_block14_2_conv
# 410 conv5_block14_concat
# 411 conv5_block15_0_bn
# 412 conv5_block15_0_relu
# 413 conv5_block15_1_conv
# 414 conv5_block15_1_bn
# 415 conv5_block15_1_relu
# 416 conv5_block15_2_conv
# 417 conv5_block15_concat
# 418 conv5_block16_0_bn
# 419 conv5_block16_0_relu
# 420 conv5_block16_1_conv
# 421 conv5_block16_1_bn
# 422 conv5_block16_1_relu
# 423 conv5_block16_2_conv
# 424 conv5_block16_concat
# 425 bn
# 426 relu
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 1024)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                32800
# _________________________________________________________________
# dense_12 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 7,070,502
# Trainable params: 6,182,182
# Non-trainable params: 888,320
# _________________________________________________________________

# %% [markdown]
# ### 학습 실행

# %%
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("jellyfish_model_retry.h5",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.0002),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])


# 훈련 및 평가
history = model.fit(train_data_std, train_labels, 
                    epochs=n_train_epoch, 
                    batch_size = 32, 
                    validation_data=(val_data_std, val_labels),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/25
# 41/41 [==============================] - 18s 202ms/step - loss: 2.1909 - accuracy: 0.2057 - val_loss: 1.6680 - val_accuracy: 0.3600
# Epoch 2/25
# 41/41 [==============================] - 4s 100ms/step - loss: 1.6769 - accuracy: 0.3070 - val_loss: 1.4755 - val_accuracy: 0.5400
# Epoch 3/25
# 41/41 [==============================] - 4s 101ms/step - loss: 1.5032 - accuracy: 0.4053 - val_loss: 1.2084 - val_accuracy: 0.6200
# Epoch 4/25
# 41/41 [==============================] - 4s 101ms/step - loss: 1.2980 - accuracy: 0.5166 - val_loss: 0.9962 - val_accuracy: 0.7100
# Epoch 5/25
# 41/41 [==============================] - 4s 101ms/step - loss: 1.1449 - accuracy: 0.5599 - val_loss: 0.8321 - val_accuracy: 0.8000
# Epoch 6/25
# 41/41 [==============================] - 4s 103ms/step - loss: 1.0278 - accuracy: 0.6187 - val_loss: 0.7533 - val_accuracy: 0.8200
# Epoch 7/25
# 41/41 [==============================] - 4s 103ms/step - loss: 0.9112 - accuracy: 0.6690 - val_loss: 0.6818 - val_accuracy: 0.8200
# Epoch 8/25
# 41/41 [==============================] - 4s 102ms/step - loss: 0.8077 - accuracy: 0.6976 - val_loss: 0.6182 - val_accuracy: 0.8600
# Epoch 9/25
# 41/41 [==============================] - 4s 102ms/step - loss: 0.7512 - accuracy: 0.7309 - val_loss: 0.5868 - val_accuracy: 0.8200
# Epoch 10/25
# 41/41 [==============================] - 4s 103ms/step - loss: 0.6569 - accuracy: 0.7672 - val_loss: 0.5842 - val_accuracy: 0.8300
# Epoch 11/25
# 41/41 [==============================] - 4s 101ms/step - loss: 0.6217 - accuracy: 0.7819 - val_loss: 0.5477 - val_accuracy: 0.8200
# Epoch 12/25
# 41/41 [==============================] - 4s 101ms/step - loss: 0.5285 - accuracy: 0.8213 - val_loss: 0.5540 - val_accuracy: 0.8400
# Epoch 13/25
# 41/41 [==============================] - 4s 101ms/step - loss: 0.4527 - accuracy: 0.8484 - val_loss: 0.5203 - val_accuracy: 0.8400
# Epoch 14/25
# 41/41 [==============================] - 4s 101ms/step - loss: 0.4436 - accuracy: 0.8461 - val_loss: 0.5011 - val_accuracy: 0.8300
# Epoch 15/25
# 41/41 [==============================] - 4s 101ms/step - loss: 0.4299 - accuracy: 0.8422 - val_loss: 0.4916 - val_accuracy: 0.8400
# Epoch 16/25
# 41/41 [==============================] - 4s 100ms/step - loss: 0.3687 - accuracy: 0.8778 - val_loss: 0.4771 - val_accuracy: 0.8600
# Epoch 17/25
# 41/41 [==============================] - 4s 101ms/step - loss: 0.3318 - accuracy: 0.8925 - val_loss: 0.4847 - val_accuracy: 0.8600
# Epoch 18/25
# 41/41 [==============================] - 4s 101ms/step - loss: 0.3038 - accuracy: 0.9002 - val_loss: 0.5099 - val_accuracy: 0.8400
# Epoch 19/25
# 41/41 [==============================] - 4s 100ms/step - loss: 0.2875 - accuracy: 0.9111 - val_loss: 0.4587 - val_accuracy: 0.8700
# Epoch 20/25
# 41/41 [==============================] - 4s 100ms/step - loss: 0.2781 - accuracy: 0.9072 - val_loss: 0.5113 - val_accuracy: 0.8400
# Epoch 21/25
# 41/41 [==============================] - 4s 100ms/step - loss: 0.2855 - accuracy: 0.9072 - val_loss: 0.5079 - val_accuracy: 0.8600
# Epoch 22/25
# 41/41 [==============================] - 4s 102ms/step - loss: 0.2526 - accuracy: 0.9157 - val_loss: 0.4850 - val_accuracy: 0.8500
# Epoch 23/25
# 41/41 [==============================] - 4s 102ms/step - loss: 0.2191 - accuracy: 0.9304 - val_loss: 0.4974 - val_accuracy: 0.8800
# Epoch 24/25
# 41/41 [==============================] - 4s 101ms/step - loss: 0.2296 - accuracy: 0.9312 - val_loss: 0.5359 - val_accuracy: 0.8800
# Epoch 25/25
# 41/41 [==============================] - 4s 101ms/step - loss: 0.2102 - accuracy: 0.9258 - val_loss: 0.4660 - val_accuracy: 0.8600

# %% [markdown]
# ### 학습 결과(accuracy, loss) 그래프

# %%
# 4. 결과를 그래프로 표시
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# val_accuracy가 최대인 에폭과 그 값을 찾기
max_val_accuracy_epoch = np.argmax(history.history['val_accuracy'])
max_val_accuracy = history.history['val_accuracy'][max_val_accuracy_epoch]


plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title(f'Accuracy over epochs({max_val_accuracy:.4f}@{max_val_accuracy_epoch})')

# val_loss가 최소인 에폭과 그 값을 찾기
min_val_loss_epoch = np.argmin(history.history['val_loss'])
min_val_loss = history.history['val_loss'][min_val_loss_epoch]

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title(f'Loss over epochs({min_val_loss:.4f}@{min_val_loss_epoch})')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 테스트 정확도

# %%
test_loss, test_accuracy = model.evaluate(test_data_std, test_labels, verbose=2)
print(f"test_loss: {test_loss} ")
print(f"test_accuracy: {test_accuracy}")
# Out:
# 2/2 - 1s - loss: 0.5450 - accuracy: 0.8974
# test_loss: 0.5450460910797119
# test_accuracy: 0.8974359035491943

# %% [markdown]
# ### 테스트 추론 결과와 라벨 비교

# %%
predicted_result = model.predict(test_data_std)  # model이 추론한 확률값. 
#print(predicted_result)
predicted_labels = np.argmax(predicted_result, axis=1)

for idx in np.random.choice(len(predicted_labels), 10):
    #idx=150 #1번째 x_test를 살펴보자. 
    print('model.predict() 결과 : ', predicted_result[idx])
    print('model이 추론한 가장 가능성이 높은 결과 : ', predicted_labels[idx])
    print('실제 데이터의 라벨 : ', test_labels[idx])

    plt.imshow(test_data[idx])
    plt.show()
# Out:
# model.predict() 결과 :  [7.0511604e-05 1.7172353e-05 9.9795556e-01 3.3341630e-04 1.4461310e-03
#  1.7712537e-04]
# model이 추론한 가장 가능성이 높은 결과 :  2
# 실제 데이터의 라벨 :  2
# model.predict() 결과 :  [9.99654889e-01 1.20846045e-04 3.03065972e-05 8.01799470e-05
#  7.64280994e-05 3.74128394e-05]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  0
# model.predict() 결과 :  [2.0689010e-06 9.9184865e-04 7.7899749e-04 7.0272931e-06 6.4105936e-04
#  9.9757904e-01]
# model이 추론한 가장 가능성이 높은 결과 :  5
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [1.3603320e-04 3.2873869e-02 1.7929275e-04 9.6672696e-01 7.5068943e-05
#  8.6930686e-06]
# model이 추론한 가장 가능성이 높은 결과 :  3
# 실제 데이터의 라벨 :  3
# model.predict() 결과 :  [0.01197999 0.02671856 0.06637434 0.04772924 0.82102656 0.02617131]
# model이 추론한 가장 가능성이 높은 결과 :  4
# 실제 데이터의 라벨 :  4
# model.predict() 결과 :  [2.0689010e-06 9.9184865e-04 7.7899749e-04 7.0272931e-06 6.4105936e-04
#  9.9757904e-01]
# model이 추론한 가장 가능성이 높은 결과 :  5
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [0.7422331  0.0713172  0.11136351 0.01996414 0.02390287 0.03121914]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [0.02746549 0.01774568 0.13139272 0.12514246 0.68649864 0.01175502]
# model이 추론한 가장 가능성이 높은 결과 :  4
# 실제 데이터의 라벨 :  4
# model.predict() 결과 :  [1.1502413e-04 7.5398167e-03 5.3505911e-03 9.8656058e-01 4.2107899e-04
#  1.2989275e-05]
# model이 추론한 가장 가능성이 높은 결과 :  3
# 실제 데이터의 라벨 :  3
# model.predict() 결과 :  [9.9347832e-05 2.2875238e-04 4.2640048e-04 1.4902900e-04 9.9695408e-01
#  2.1423409e-03]
# model이 추론한 가장 가능성이 높은 결과 :  4
# 실제 데이터의 라벨 :  4

# %% [markdown]
# ## 학습 결과 기록
#
# ## ResNet V2
# ### no_aug
# model-2, no aug, dense 32
# ![image.png](attachment:image.png)
#
# model-2, no aug, dense 32, batchnormal
# ![image-3.png](attachment:image-3.png)
#
# model-2, no aug, dense 32, batchnormal, resnet retrain from 158(conv5 block1)
# ![image-4.png](attachment:image-4.png)
#
# model-2, no aug, dense 32, batchnormal, resnet retrain from 76(conv3 block4)
# ![image-5.png](attachment:image-5.png)
#
# model-2, no aug, dense 32, batchnormal, resnet retrain from 177(conv5 block3)
# ![image-6.png](attachment:image-6.png)
#
# 위와 같고 aug(90도 rotate, contrast)
# ![image-7.png](attachment:image-7.png)
#
# model-2, no aug, dense 32, batchnormal, resnet retrain from 177(conv5 block3) + rgb_stardization
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ## MobileNet V2
#
# no aug, dense 32, no retrain
# ![image.png](attachment:image.png)
#
# no aug, dense 32, retrain from 143 (마지막 block?) epoch 50
# ![image-2.png](attachment:image-2.png)
#
# 위와 같음(no aug, dense 32, retrain from 143 (마지막 block?) epoch 50) + rgb_standardization
# - 특징 : metric의 수렴이 굉장히 빠르다. 반면, val metric의 모양도 안정적이다.
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## DenseNet
#
# model-2, no aug, dense 32, batchnormal, densnet no retrain + rgb_stardization
# ![image.png](attachment:image.png)

# %% [markdown]
# # DenseNet
# model no aug, dropout(0.225), den32, dropout(0.225), (드랍아웃 1개일때랑 비교 필요)
# ![image.png](attachment:image.png)

# %% [markdown]
# # MobileNet
# model4, no aug, dropout(0.225), den32, dropout(0.225), data added
# ![image.png](attachment:image.png)

# %% [markdown]
# # MobileNet
# model4, no aug, dropout(0.3) den32, dropout(0.3) data added
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Densenet
# model no aug, dropout(0.35), den32, dropout(0.35)
# ![image.png](attachment:image.png)
